# %%
from ta import add_all_ta_features
from ta.utils import dropna
from ta.volatility import BollingerBands

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Documentation: https://technical-analysis-library-in-python.readthedocs.io/en/latest/

# %%
company_info = pd.read_csv(r"C:\Users\Matt\Downloads\Git\cis4400fall2024\data\companyInfo.csv")
otc_data_dict = pd.read_excel(r"C:\Users\Matt\Downloads\Git\cis4400fall2024\data\otc_data_dictionary.xlsx")
otc_security = pd.read_

# %%
company_info.head()
# Out:
#   Symbol             Security Name          Tier    Price  Change %      Vol  \
# 0  AAAIF  ALTERNATIVE INVSTMENT TR  Pink Current   0.0000       NaN        0
# 1  AAALF        AAREAL BANK AG AKT  Pink Current  31.9900       NaN        0
# 2  AAALY   AAREAL BANK AG UNSP/ADR  Pink Current  34.6500       NaN        0
# 3   AABB        ASIA BROADBAND INC  Pink Current   0.0285     2.518  8396652
# 4  AABVF         ABERDEEN INTL INC  Pink Current   0.0324       NaN        0
#
#                   Sec Type  Country    State
# 0                     Fund      NaN      NaN
# 1  Foreign Ordinary Shares  Germany      NaN
# 2                     ADRs  Germany      NaN
# 3             Common Stock      USA   Nevada
# 4  Foreign Ordinary Shares   Canada  Ontario

# %%
otc_data_dict.head()
# Out:
#             Data Element                                        Description   \
# 0            Security ID   OTC Markets Group unique identifier for security
# 1             Company ID   OTC Markets Group unique company identifier fo...
# 2         Trading Symbol                                  US markets symbol
# 3           CUSIP Number   S&P Unique Security Identifier. This field wil...
# 4  Security Name (Issue)       OTC Markets Group supplied name for security
#
#   Data Type
# 0   Integer
# 1   Integer
# 2  Char(10)
# 3   Char(9)
# 4  Char(50)
